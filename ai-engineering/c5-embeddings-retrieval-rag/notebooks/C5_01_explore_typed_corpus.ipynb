# %% [markdown]
# # C5.01 Corpus agenti - Tema 2
#
#
# Scop: ne uităm la `data/corpus_typed.json`, verificăm distribuția bulelor și alegem ce exemple merită păstrate pentru vector store.

# %% [markdown]
# ## 1. Setup

# %%
from pathlib import Path
import os
import pandas as pd

PROJECT_ROOT = Path(r"C:\PROJECTS\echochamber-app")
os.chdir(PROJECT_ROOT)
DATA_PATH = Path("data/typed/corpus_typed.jsonl")

# %%
DATA_PATH
# Out:
# WindowsPath('data/typed/corpus_typed.jsonl')

# %% [markdown]
# ## 2. Încărcăm corpusul

# %%
df = pd.read_json(DATA_PATH, lines=True)
df.head(2)
# Out:
#                                           id       source_channel  \
# 0  yt_iH8jB4NlV9Y_UgxGvCWbzsvB3I-nSy54AaABAg  georgesimionoficial
# 1  yt_iH8jB4NlV9Y_UgwiYbOpe89FfXbeIpl4AaABAg  georgesimionoficial
#
#   channel_family                                        video_title  \
# 0  sovereigntist  Episodul 2: Cum ne-au furat alegerile - Turism...
# 1  sovereigntist  Episodul 2: Cum ne-au furat alegerile - Turism...
#
#                                                 text  low_information  \
# 0  Metoda votului cetatenilor din Republica Moldo...            False
# 1  Doamne cu atâtea dovezi și nicio instituție in...            False
#
#    pre_filtered target_specific target_refined        target_l1  ...  \
# 0         False     nicusor_dan    nicusor_dan  Instituții stat  ...
# 1         False          simion         simion    Sovereigntist  ...
#
#   repr_pluralist_present repr_pluralist_strength dem_procedure_rejected  \
# 0                  False                       0                  False
# 1                  False                       0                  False
#
#    dem_procedure_defended  call_to_action_present  call_to_action_strength  \
# 0                   False                    True                        1
# 1                   False                   False                        0
#
#    confidence            discourse_type          discourse_subtype  \
# 0         0.9  T2_grievance_anti_sistem   grievance_conspiratorial
# 1         0.9     T1_suport_personalist  suport_afectiv_suveranist
#
#    type_confidence
# 0             high
# 1           medium
#
# [2 rows x 38 columns]

# %% [markdown]
# ## 3. Vedem structura datelor

# %%
len(df)
# Out:
# 17886

# %%
print("Coloane:")
df.columns
# Out:
# Coloane:
# Index(['id', 'source_channel', 'channel_family', 'video_title', 'text',
#        'low_information', 'pre_filtered', 'target_specific', 'target_refined',
#        'target_l1', 'target_l2', 'stance_to_target', 'primary_target_hint',
#        'target_confidence', 'inst_neg_present', 'inst_neg_strength',
#        'inst_pos_present', 'inst_pos_strength',
#        'epist_hidden_coordination_present',
#        'epist_hidden_coordination_strength',
#        'epist_evidence_verification_present',
#        'epist_evidence_verification_strength',
#        'geo_anti_external_domination_present',
#        'geo_anti_external_domination_strength',
#        'geo_pro_external_anchoring_present',
#        'geo_pro_external_anchoring_strength', 'repr_personalist_present',
#        'repr_personalist_strength', 'repr_pluralist_present',
#        'repr_pluralist_strength', 'dem_procedure_rejected',
#        'dem_procedure_defended', 'call_to_action_present',
#        'call_to_action_strength', 'confidence', 'discourse_type',
#        'discourse_subtype', 'type_confidence'],
#       dtype='str')

# %%
df["discourse_type"].value_counts(dropna=False)
# Out:
# discourse_type
# T2_grievance_anti_sistem      7583
# T1_suport_personalist         4624
# T6_afectiv_pozitional         3726
# T4_conspiratie_externalism    1506
# T3_opozitie_suveranista        261
# T5_pro_democratic_european     186
# Name: count, dtype: int64

# %%
## Exemplu de text pentru fiecare tip de discurs

# %%
for bubble in df["discourse_type"].value_counts().index:
    print("\n" + "="*80)
    print(bubble)
    print("="*80)
    
    sample = df[df["discourse_type"] == bubble]["text"].dropna().head(5)
    
    for i, text in enumerate(sample, 1):
        print(f"\n{i}. {text[:50]}")
# Out:
# ================================================================================
# T2_grievance_anti_sistem
# ================================================================================
#
# 1. Metoda votului cetatenilor din Republica Moldova a
#
# 2. Calin Georgescu si George Simion la puscarieeee!!
#
# 3. S-au furat prin liste suplimentare, într-un sat di
#
# 4. Eu nu cred că caracatița poate fi dată la parte !E
#
# 5. Știu ca există un sistem de vot electronic în care
#
# ================================================================================
# T1_suport_personalist
# ================================================================================
#
# 1. Doamne cu atâtea dovezi și nicio instituție intern
#
# 2. Noi oricum știm asta dar întrebarea mea este domnu
#
# 3. Felicitări și RESPECT George Simion! Nu te opri! V
#
# 4. Haideți in stradă pe 20 iulie!!!! Să dăm jos hoții
#
# 5. MILIOANE DE ROMÂNI DEMNI SUNTEM ALĂTURI DE TINE,GE
#
# ================================================================================
# T6_afectiv_pozitional
# ================================================================================
#
# 1. Adevarul sa fie facut prezent si rezultatul sa fie
#
# 2. Ceea ce face este demn de noi romanii adevarati .
#
# 3. Si de trebuie deposite de combustibil degeaba avem
#
# 4. Dumnezeu sa Binecuvinteze Partidul Aur, 🇹🇩🙏 Români
#
# 5. Felicitari pentru discurs! ❤️🙏🇷🇴 Si pentru consecv
#
# ================================================================================
# T4_conspiratie_externalism
# ================================================================================
#
# 1. Atunci daca aveți dovezi împotriva la Maya Sandu d
#
# 2. Dom-le am văzut cu ochii nostrii cum sa fraudat to
#
# 3. Domnule Simion, cine sunt oamenii acestia si in ce
#
# 4. George pina Mr Trump nu is baga mina nu aveti sans
#
# 5. 2:51 Caaaat? 10.000 Euro la 100.000 urmăritori? O
#
# ================================================================================
# T3_opozitie_suveranista
# ================================================================================
#
# 1. Să zicem că ar fi fost 500 de autocare prin absurd
#
# 2. Eu înteleg că mănânci căcat dar chiar nu ai nicio
#
# 3. deci dovezi lipsa, doar marturii inventate.. bravo
#
# 4. Puneti mana si mai cercetati, nu mai credeti toate
#
# 5. George dacă tu știi că te-au furat atunci nu trebu
#
# ================================================================================
# T5_pro_democratic_european
# ================================================================================
#
# 1. Este ilegal și extrem de riscant să încerci să vot
#
# 2. Nu ajută să vedem asta trebuie să folosiți datele
#
# 3. Mă voi realizați că votul s-a încheiat și Nicușor
#
# 4. PERSPECTIVA MEA E CLA 2:22 RA, E OPTIMA! VOTEZ NIC
#
# 5. PERSPECTIVA MEA E CLARA, E OPTIMA. VOTEZ NICUSOR D

# %% [markdown]
# # 4. Pastram doar 150 de bula

# %%
# Alegem un subset simplu pentru curs: maximum 150 texte per bulă

N_PER_BUBBLE = 150

df_sample = (
    df[df["discourse_type"].notna()]
    .sort_values("type_confidence", ascending=False)
    .groupby("discourse_type", group_keys=False)
    .head(N_PER_BUBBLE)
    .copy()
)

df_sample["discourse_type"].value_counts()
# Out:
# discourse_type
# T3_opozitie_suveranista       150
# T2_grievance_anti_sistem      150
# T1_suport_personalist         150
# T4_conspiratie_externalism    150
# T5_pro_democratic_european    150
# T6_afectiv_pozitional         150
# Name: count, dtype: int64

# %%
# Păstrăm doar coloanele utile și salvăm corpusul pentru etapa următoare

keep_cols = [
    "id", "text", "source_channel", "channel_family", "video_title",
    "target_refined", "stance_to_target",
    "confidence", "discourse_type", "discourse_subtype", "type_confidence"
]

df_sample = df_sample[keep_cols].drop_duplicates(subset="text").copy()

OUT_PATH = Path("data/typed/corpus_c5_sample.jsonl")
df_sample.to_json(OUT_PATH, orient="records", lines=True, force_ascii=False)

print(df_sample.shape)
print(OUT_PATH)
df_sample.head(2)
# Out:
# (896, 11)
# data\typed\corpus_c5_sample.jsonl
#                                               id  \
# 17885  yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg
# 15394  yt_joXkZDqGZQU_Ugyqb1XZ7P8GTnJS_4p4AaABAg
#
#                                                     text     source_channel  \
# 17885  Am toată încrederea că oameni ( de bine ) ca :...  AlephNewsOfficial
# 15394  Semneaza Bo$$ ca la urmatoarele alegerii nu ma...       NicusorDanRO
#
#          channel_family                                        video_title  \
# 17885        mainstream  ATENȚIE: România e „binevenită” să aplice iar ...
# 15394  mainstream_actor  🟢 Declarații de presă comune cu Președintele U...
#
#       target_refined stance_to_target  confidence            discourse_type  \
# 17885         simion             anti         0.9   T3_opozitie_suveranista
# 15394    nicusor_dan             anti         0.9  T2_grievance_anti_sistem
#
#            discourse_subtype type_confidence
# 17885        opozitie_difuza          medium
# 15394  grievance_mobilizator          medium

# %% [markdown]
# ## 5. Exportul bulelor finale
# În această etapă transformăm corpusul tipologizat în fișiere separate, câte unul pentru fiecare bulă finală.
# Codurile `T1`, `T2`, `T3`, `T4`, `T5` vin din adnotare, dar în aplicație folosim numele finale ale agenților:
# | Agent | Personalitate | Cum vorbește | Ce îl definește |
# |---|---|---|---|
# | Personalist-salvator | devotat, admirativ, sigur | laudativ, emoțional, încrezător | vede liderul ca soluție excepțională |
# | Anti-sistem | furios, suspicios, dezamăgit | acuzator, moralizator, direct | vede instituțiile și „sistemul” ca profund compromise |
# | Anti-suveranist | critic, vigilent, defensiv | contestatar, mai argumentativ | respinge liderii și discursul suveranist |
# | Conspiraționist | alarmist, hiper-suspicios | speculativ, revelator, totalizant | explică evenimentele prin forțe ascunse și actori externi |
# | Pro-european | normativ, moderat, legalist | sobru, justificativ, procedural | apără regulile, instituțiile și ancorarea europeană |
# `T6_afectiv_pozitional` nu devine agent principal în C5. Rămâne categorie transversală / rezervă.

# %%
BUBBLES = {
    "T1_suport_personalist": {
        "agent": "Personalist-salvator",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "T2_grievance_anti_sistem": {
        "agent": "Anti-sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "T3_opozitie_suveranista": {
        "agent": "Anti-suveranist",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "T4_conspiratie_externalism": {
        "agent": "Conspiraționist",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "T5_pro_democratic_european": {
        "agent": "Pro-european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

# %%
"""
OUT_DIR = Path("data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

N_PER_BUBBLE = 50

for old_type, meta in BUBBLES.items():
    bubble_df = (
        df_sample[df_sample["discourse_type"] == old_type]
        .drop_duplicates(subset="text")
        .head(N_PER_BUBBLE)
        .copy()
    )

    bubble_df["agent"] = meta["agent"]
    bubble_df["slug"] = meta["slug"]
    bubble_df["personality"] = meta["personality"]
    bubble_df["speaks"] = meta["speaks"]
    bubble_df["definition"] = meta["definition"]
    bubble_df["source_type"] = old_type

    out_path = OUT_DIR / f"{meta['slug']}.jsonl"
    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

    print(f"{meta['agent']}: {len(bubble_df)} texte -> {out_path}")

"""
# Out:
# '\nOUT_DIR = Path("data/bubbles")\nOUT_DIR.mkdir(parents=True, exist_ok=True)\n\nN_PER_BUBBLE = 50\n\nfor old_type, meta in BUBBLES.items():\n    bubble_df = (\n        df_sample[df_sample["discourse_type"] == old_type]\n        .drop_duplicates(subset="text")\n        .head(N_PER_BUBBLE)\n        .copy()\n    )\n\n    bubble_df["agent"] = meta["agent"]\n    bubble_df["slug"] = meta["slug"]\n    bubble_df["personality"] = meta["personality"]\n    bubble_df["speaks"] = meta["speaks"]\n    bubble_df["definition"] = meta["definition"]\n    bubble_df["source_type"] = old_type\n\n    out_path = OUT_DIR / f"{meta[\'slug\']}.jsonl"\n    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)\n\n    print(f"{meta[\'agent\']}: {len(bubble_df)} texte -> {out_path}")\n\n'

# %% [markdown]
# ## 6. Alege agentul tău și verifică textele
# Fiecare membru al echipei lucrează pe un singur agent.
# Datele vin din `df_sample`, iar agentul este legat de eticheta tehnică `discourse_type`.
# Scopul este să alegi aproximativ 50 texte bune pentru agentul tău.

# %%
# Alegeți un agent și încărcați textele corespunzătoare pentru etapa următoare
AGENTS = {
    "Personalist-salvator": {
        "type": "T1_suport_personalist",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "Anti-sistem": {
        "type": "T2_grievance_anti_sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "Anti-suveranist": {
        "type": "T3_opozitie_suveranista",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "Conspiraționist": {
        "type": "T4_conspiratie_externalism",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "Pro-european": {
        "type": "T5_pro_democratic_european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

MY_AGENT = " -------------------------"  # Alegeți unul dintre agenți: "Personalist-salvator", "Anti-sistem", "Anti-suveranist", "Conspiraționist", "Pro-european"

meta = AGENTS[MY_AGENT]

my_df = (
    df_sample[df_sample["discourse_type"] == meta["type"]]
    .drop_duplicates(subset="text")
    .copy()
)

print("Agent:", MY_AGENT)
print("Tip discurs:", meta["type"])
print("Texte disponibile:", len(my_df))

my_df[["id", "type_confidence", "discourse_subtype", "text"]].head(2)
# Out:
# Agent: Anti-sistem
# Tip discurs: T2_grievance_anti_sistem
# Texte disponibile: 149
#                                               id type_confidence  \
# 15394  yt_joXkZDqGZQU_Ugyqb1XZ7P8GTnJS_4p4AaABAg          medium
# 11534  yt_pO0JOPX1I7Q_UgyExKkzQjU2eOVTG7J4AaABAg          medium
#
#            discourse_subtype  \
# 15394  grievance_mobilizator
# 11534  grievance_mobilizator
#
#                                                     text
# 15394  Semneaza Bo$$ ca la urmatoarele alegerii nu ma...
# 11534  ESTE NEVOIE DE O FESTAÑIE LA TOATE NIVELURILE ...

# %% [markdown]
# ### Cum verifici textele
# Citește textele afișate mai jos.
# Dacă un text este slab, copiază ID-ul lui în lista `REMOVE_IDS`.
# Elimină texte prea scurte, duplicate, ambigue sau care nu exprimă clar vocea agentului.|
#
# - pot sa folosesc un notepad pentru IDs
# daca nu gasesti 50 de comentarii bune, incarca mai multe.
# - poti folosi si alte metode (export text, csv) pentru vizualizarea si alegerea comentariilor

# %%
for _, row in my_df.head(70).iterrows():
    print("=" * 80)
    print("ID:", row["id"])
    print("Confidence:", row["type_confidence"])
    print("Subtype:", row["discourse_subtype"])
    print(row["text"][:700])
# Out:
# ================================================================================
# ID: yt_joXkZDqGZQU_Ugyqb1XZ7P8GTnJS_4p4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Semneaza Bo$$ ca la urmatoarele alegerii nu mai iesi presedinte. Noi ca tara si popor suntem rupti in cur cu salarii de vietnam si preturi de SIngapore.... dar ajutam cu banii Ukraina ... alta tara corupta la fel si Rusia
# ================================================================================
# ID: yt_pO0JOPX1I7Q_UgyExKkzQjU2eOVTG7J4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# ESTE NEVOIE DE O FESTAÑIE LA TOATE NIVELURILE STATULUI ADMINISTRATIV ȘI POLITIC
# ================================================================================
# ID: yt_6_Hc2S02Duw_Ugz2UatUIFNpL1SP7u54AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Orcii fac ore suplimentare!! Bravo! Daca ati muncii asa si in a arara escrocii si securistii corupti in aur psd si cati pe unde s a u ascuns😊
# ================================================================================
# ID: yt_YFbJhBc_9jo_Ugx9GFXKkTHUqa4NYcZ4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Câtă nesimțire!!! Câtă hoție pe fațaă!!! Ce răspunsuri ridicole care mă fac să fiu înecat de furie!!! Dar românii sunt cu frica de Dumnezeu și deși foarte mulți dintre ei vor înțelege situația, nu vor face nimic în sensul ăsta, să nu cumva să-l supere pe popă care va asmuți asupra lor mânia atotpuetrnicului.
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgzrK_gcZVEbQXhfL614AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Biserica, aceasta sinecura de sifonat bani, este cea mai eficienta unealta pentru prostirea si manipularea maselor! Nicaieri in cartile sfinte, nu scrie ca Bor trebuie sa-si cumpere proprietati sau ca trebuie sa faca politica, dimpotriva.
# ================================================================================
# ID: yt_pO0JOPX1I7Q_Ugybt7d7rEbankiluHx4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Știi ce cîștiga Robert, spălații pe creier? Bani, multi bani pe care îi primesc din banii noștrii! Singura soluție de a scăpa de acești paraziți este modificarea legii partidelor și să se termine cu banii dați de la buget partidelor! Dacă vor să plătească presă să îi pupe în cur , să plătească din banii lor!
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgxK82Kwfz6FIA_zVdx4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# B.O.R= cea mai de succes instituție în îndepărtarea omului de Dumnezeu.
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgwVAlmHsAzDHZhxe1l4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Ăștia din Bor nu au rusine, își vad doar de ambițiile lor și nu se uita în jur să vadă nevoile reale din societate 😔
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgybSZmCUQxHiXoSu1N4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# astia isi doresc in mod expres sa ne impinga in mainile AUR...
# ================================================================================
# ID: yt_im3QoqSgfDo_Ugxaq3uTpwVyAXPexyh4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Un ȘARLATAN care s- a gândit să lupte împotriva celor care i- a dat din palmă să mănânce ,,,,, Adică,ai milă de drac ,,,,, și el scoate coarne ! Păi nu a lucrat cu Iliescu, Român,Ponta, Geoană, Dragnea,,,,,,, Și spune :. "Toată clasa politică este făcută praf! " Păi ce ai păzit,,,,, bre?
# ================================================================================
# ID: yt_YFbJhBc_9jo_Ugz3WbdPX9dFqEPk1XV4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Sa-i fie rusine lui Bolojan pentru ce face poporului roman! In timp ce noi ne spetim sa muncim ca sclavii ca sa-i producem lui taxe, in timp ce s-au marit toate iar el a taiat de la mame, pensionari, handicapati, ne contorizeaza fiecare ban fara sa sustina de nici un fel investitiile sau sa creeze conditii sa se intoarca acasa romanii plecati in afara, el da moka la BOR de peste hotare, ca alea erau prioritatile noastre...sa se duca naibii de unde a venit si sa ne lase in pace, ajunge atata bataie de joc!
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgwGLtm8Hr---efEoJd4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Si pulimea emigranta trebuie sifonata de bani in numele domnului. Personal, i-as trimite pe toti la ala pentru care lucreaza si acela sa le plateasca salariile.
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgxXpc08OwXgdwE-T514AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Da bravo DRP, cereți bani ca pătrunjel in piață, iar cand sunteti întrebați nu aveti nici un plan administrativ in folosirea lor. Mergeti la cerșit dar la semafoare nu la guver! Dati bani pentru educație fara ea nu exista credință si prosperitate, doar lăcomie si minciună.
# ================================================================================
# ID: yt_YFbJhBc_9jo_Ugx2NASf3lEFIcfHW9J4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Foarte bună ediția aceasta, ar trebui distribuită peste tot să vadă oamenii ipocrizia acestui guvern de mizerabili.
# ================================================================================
# ID: yt_UDPyC0EuCLg_UgyYlVG6pNghP6Kf7Qd4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# a3a oara poate e cu noroc , daca nu vor incerca sefii tvr sa si bage coada !!!respect dle Patraru sa ramaneti mereu la nivel inalt , integru si de neclintit in fata presiunilor politice !! presa a ramas inn2 stalpi : Dragos patraru si Radu banciu , in rest toti sunt manjiti cu bani publici !!!
# ================================================================================
# ID: yt_im3QoqSgfDo_UgzvRD6tFsdz_MMThZF4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Fi.var prostu' al dreaq. 😂😂😂 Bah sunteti dobitoci rau. Si voi si Georgescu si Nicusor Dan si toti 😂😂😂 i'ti ai naibii de nebuni. 😂😂😂
# ================================================================================
# ID: yt_UDPyC0EuCLg_UgzKoaMUFl5rp3pIYlt4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Profesorii ar trebui sa faca greva generala si sa nu renunte pana nu obtin 6% din Pib. Plus noi, parintii copiilor ar trebui sa iesim alaturi de ei. O sa zica unii dar asta ii afecteaza pe copii acum o sa piarda nu stiu ce examene. Pai cred ca pana acum cu inactiunea si apatia asta din societatea romaneasca vis a vis de educatie au fost afectate generatii de copii. Va dati seama cati am pierdut pe drum de-a lungul anilor. Un adult analfabet nu se mai intoarce la scoala in ciclul primar.
# ================================================================================
# ID: yt_ZAJeeVgVvYc_UgyhipxhrCuglrv84Ep4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# psd și aur, împreună cu șefii magistraților, frânează sistematic România, și chiar o sugrumă, pentru a se fura în continuare ! Trebuie o schimbare, nu o stagnare...
# ================================================================================
# ID: yt_qkGhsJFft00_Ugw-iAwsTHxjB4w0XlV4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# "Tinerii sunt victimele libertatii". Penibili. Datorita voua, s-a carat lumea in vest dupa falimentul protestelor colectiv. Ne este scarba atat de alde tov. Hurezeanu care statea bine merci in libertate in Germania Federala in timp ce romanii traiau sub una dintre cele mai crunte dictaturi; cat si de alde tov. Georgescu sau Simion care vor sa readuca romanica unde era in iunie '90
# ================================================================================
# ID: yt_pO0JOPX1I7Q_UgxodFOAm4ETQRpmwzR4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# De vina sunt acei concetățeni care, la vot, nu au pe cine vota, stau acasă pentru că votul lor nu contează. I-a să iasă la vot 90% din populație, să vezi atunci care sunt partidele care ne reprezintă.
# ================================================================================
# ID: yt_PrLWSF8Ypc8_UgwUAojMJz05qZuqw0p4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Si Mocanu mai este artist, si voi marile televiziuni promovati scursurile astea
# ================================================================================
# ID: yt_6_Hc2S02Duw_UgxAY6nS7DtmTxJt6Ll4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Wow ! "Ii asigur pe Romani ca nu au motive de ingrijorare. Tara LOR este o tara sigura" Asta nu se considera roman. O fi evreu care ne baga in rahat pentru israel Trebuie suspendat. Nu avem ce ajuta SUA sa atace alte state suverane.
# ================================================================================
# ID: yt_PrLWSF8Ypc8_Ugwt79B9y0h_lYaBaIZ4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Ma ma, apoi toate TV ne publicați același știre, mai lăsați ne în pula, dacă nu aveți ostirii, mai puneți lacătul pe televiziuni ?
# ================================================================================
# ID: yt__qs5Iw5JdA8_UgxYnsNdrHl_ZoIlnbV4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Ati ajuns de toata jena.Cum ma sa le dati atata importanta acestor mizerii?
# ================================================================================
# ID: yt__KWvjqg67Fk_UgxrVes2KLjJn8MvX6l4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media_conspiratorial
# ce surpriza, omg, nimeni nu putea sa vada ca se v-a intampla asta acum 10 ani, total surpriza
# ================================================================================
# ID: yt__KWvjqg67Fk_Ugx8Ts6vuGBE6swZQOd4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media_conspiratorial
# Mizeria aia de video cu politisti amenintand celebriatea de manelist cu fascicole laser, evident făcut cu AI, va reprezinta ca post Tv national? Trebuia sa empatizez?
# ================================================================================
# ID: yt_pO0JOPX1I7Q_UgzJS4G8fSh1-mHx6ep4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Usr cu Fritz cu tot, trebuiesc scosi in afara legii! Numai nazistii au mai fost atat de inumani si sinistri... Discutie lui cu muc sunt ilegale si ar trebui investigate.
# ================================================================================
# ID: yt_eciCyRaQcWM_UgyKVLK_YuuoGQcy6NB4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media_conspiratorial
# Nicușor este când turnător la securitate, când legionar, când nu mai știu ce. Nicușor este din Făgăraș, unde au rezistat oamenii, partizani cum se numeau ei, în munți împotriva bolșevicilor, sigur că erau și legionari printre ei, dar faptul ăsta ține de eroism și iubire de patrie. Dar voi la G4 ați început să răspundeți la comenzile șefului, nu știi de ce vă mai bagă lumea în seamă. Mai rămâne să faceți și un interviu cu maestrul Cristoiu, zis Coroiu, să vă zică el cum stă treaba de fapt. Dacă aveați un minim respect, v-ați fi luat bănuții și încetați activitatea, dar așa să faceți "presă" în continuare este penibil.
# ================================================================================
# ID: yt_sFsjXSoAc-8_UgzTT3EPIk5YWjkqa454AaABAg
# Confidence: medium
# Subtype: grievance_anti_media_conspiratorial
# Dacă agenții de propagandă precum G4 Media încep să ne spună că mâncăm prea mult înseamnă că trebuie să ne pregătim de foame 🤣
# ================================================================================
# ID: yt_0b2_71jAaQs_UgwqiugjPksyUhCX3qx4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Ati promis ca puneti sefi la servicii in februarie si poate sa speram ca le mai reformati naibii structurile astea comuniste care ne distrug vietile !Ma tem ca sinteti Iohanis 2 ! Ca presedinte sa promiti ceva si sa nu te tii de cuvint e maxim de rusinos !Daca in turul doi apare o figura de calitate il voi vota ! Ati promis ca faceti patinoarul Flamaropol si incepeti o sala polivalenta !Alta vrajeala .
# ================================================================================
# ID: yt_bee6nXyzJ_E_UgyguhcTNvNf4Ck6Q0J4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Dumneata din care categorie faci parte? Comuniștii vechi sau cei noi? Ești unul dintre “privilegiați” din țara asta care face parte din amândouă!
# ================================================================================
# ID: yt_0b2_71jAaQs_UgzNeYs5yuZJmwsu5jV4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Domnule președinte chiar nu vezi corupția și hoția la nivelul politic. De ce nu incercati să eliminați corupția și înlocuirea politicienilor corupți și schimbate legile pentru hoți. La energie câștigă niște șmecheri.Totul este umflat artificial .
# ================================================================================
# ID: yt_Vpfd5aXku18_Ugx0p8g2R4e1vkTgehN4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Doamne fereste! Nivelul de trai a scazut foarte mult,prin pierderea locurilor de munca,multi au plecat in afara,educatia,sanatatea,economia in general sint praf!!!🤔Acesta este adevarul!!! Ce pensii si salarii au romanii!!!??? Si ce preturi la toate produsele sint in Romania!!!???🤔Cum era Romania si cum este acum!!?? Dar speram in mai bine!!!.
# ================================================================================
# ID: yt_VbePYOnsSIE_Ugz0gvcWxEtzh0gbnXR4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Domnule Turcescu, daca considerati ca merita, va rog sa faceti o radiografie a consecintelor care le-au avut pentru noi, “activitatea” tuturor ministirilor usr, din ultimii 6 ani.
# ================================================================================
# ID: yt_VbePYOnsSIE_UgyVXdX1uNddpRhxVtZ4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Salut Robert! 1. Justiția nu funcționează! E confiscata .2 Usr- istii nu știu de rușine! Trebuie aplicată FRICA ! legal ( JUSTITIE ) De ce trebuie sa poporul in strada ? Noi îi plătim sa nu ne persifleze încrederea! Sa ne ocrotească, si sa facă politici/publice corecte ! Oana Toiu e o Tutamela nespalată ! O rușine! Trebuie diferita justiției la ora 05 dimineața!
# ================================================================================
# ID: yt_VbePYOnsSIE_UgyfeATjgHw7AqsM9UV4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# E NUMAI VINA NOASTRA ! TREBUIE SA IESIM IN STRADA, SA URLAM CAT NE TIN PLAMANII SI SA NU PLECAM PANA NU PLEACA EI !
# ================================================================================
# ID: yt_VbePYOnsSIE_UgxXLhX4nfZm6cs9Nmx4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Și fără doctorat în medicină se înțelege ce fel de conducere este la Cotroceni...🤮🤮🤮🤮 Să-și ia catrafusele și să plece cât mai repede de la portar până la președinție
# ================================================================================
# ID: yt_UDPyC0EuCLg_Ugx2HiPEnrKDFYMxZMp4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Nu va prinde vara la TVR. Dar bravo ! În sfârșit are cineva curajul sa spună adevărul intr-o mare de pupincuriști ai puterii .
# ================================================================================
# ID: yt_bee6nXyzJ_E_UgxeA-QRrumI7pHc4014AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Daca nici acum nu intelegeti cine este cg si il mai votati,sunteti de doamne fereste...in afara de boti...Daca nu se anulau alegerile,oricum nu ieseai presedinte...
# ================================================================================
# ID: yt_ThNuJxTDf6c_Ugyy-vX2VMKgqpwOH414AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Jigodiile mafioase ale sistemului dictatorial sint invitati sa nu mai latre minciuni la televiziunile corupte. Inchideti tele manipularea . Dezinformeaza populația. Autorul genocidului , al acțiunilor criminale organizate in plan international sint Netanyahu/ israel assasins la populația civilă, de copii si femei fără apărare , de obiective care nu sint militare.
# ================================================================================
# ID: yt_bee6nXyzJ_E_Ugw8gBbH1k20kKkJNTF4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Dar ști de ce îți scad privitorii? De fapt ști,apoi ști de ce nu prea mai ai pe cine sa inviți? Suntem multi care știm de ce,ai fost lider de audiență,dar nu mai ești și nu o sa fi degrabă,după câte vedem noi,astia din popor,plebea.Ne-ai reprezentat cuvântul la un moment dat,dar,dar cuvântul tău s-a schimbat radical.ce vedem noi câteva mii de români plecați în străinătate vad și ai noștri din tara. Ești altfel,ești schimbata,nu in bine. Cam știm jocurile voastre,sa nu credeți că suntem tâmpiți,sa nu vă așteptați să vă mai sprijinim sau votam.
# ================================================================================
# ID: yt_7PIhnqzrSDw_UgwA_KVMauPEUFGfeXR4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media_conspiratorial
# Dar timp de 26 de ani de ce ai tacut ,? Te ai desteptat cu venirea la guvernare a lui Bolojan ,a presedintelui usrist ? Spune adevarul cu mana pe Biblie
# ================================================================================
# ID: yt__PIes5dU7Zg_Ugy4KcANoTKbWS_eM814AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Simion este un escroc , și - a lăsat parlamentarii acasă , a spus râzând că AUR vrea pace , dar au înlesnit votul " pentru " ! Dacă ajungea el președinte , era la fel ca Tăntălăul onest ! 🤮🤮🤮
# ================================================================================
# ID: yt_1E2cXajO16k_UgyYwvXnsh7bUBkwG_54AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Pt orice cult trebuie oprite finanțările punct Por trăii din colecte lunare și vor trăii liniștiți Cu cit îi finanțează mai mult cu atita fură mai tare Viața bună au săracii popi ei se văita și se plimbă cu Xuri și mertane Sărăciile
# ================================================================================
# ID: yt_joXkZDqGZQU_Ugx0o-pGAzWrpPorhNh4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Scoateți instituțiile la treabă să sancționeze căci pe cetățeni dacă nu îi arzi la bani nu se modelează corespunzător. România este o țară ineficientă, infrastructura nu ne permite să economisim. Este cald afară dar nu pot circula cu bicicleta deoarece este foarte poluat. Măriți impozitul pe autoturism personal mai mult că acolo se duce mult din devalorizarea monezii.
# ================================================================================
# ID: yt_joXkZDqGZQU_UgyTRSQo9EQbGeE-DP54AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Vai NU MAI POT CU TRADUCATORUL ASTA. Nu mai am rabdare ,ma ustura urechiel nu intekeg nimjc. Va rog MUUULLTTTT. Nu mai vrem traducatori. Băgati doar subtitrare si gata.
# ================================================================================
# ID: yt__PIes5dU7Zg_UgzmLTtZF57kFlHcoBp4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Daca am scăpat ca prin urechile acului de razboiu cu rușii, pentru apărarea Ucrainei, acum, ...tinet-va !
# ================================================================================
# ID: yt_YrAie1rs1gM_UgzEuhhuL5NXM8_u0Tp4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# jos cu mafiile din tara, jos cu mafia doctorilor, a apelor, a vamilor... hai cu trezirea !!!
# ================================================================================
# ID: yt_im3QoqSgfDo_UgxlteTPBmVcK8nEiqp4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Grijă mare grijă mare să nu fie chiar el SISTEMUL de care vorbește nu mișcă nimic doar se plimbă pe la poliție și pe la tribunal să vândă iluzii și speranțe . Repet grijă mare
# ================================================================================
# ID: yt_33ypGncXCIw_UgxkeFL_6egpvadzhGp4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Cand va ganditi ca astia dau sentinte si baga la puscarie oameni
# ================================================================================
# ID: yt_33ypGncXCIw_UgxJ1WUJvAUiQsfh0kN4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# CU TIPETE DNA JUDECATOR NU SE LUCREAZA CU SETATENILOR.REREVIZUITI COMPORTAMENTUL .😮😮😮
# ================================================================================
# ID: yt_0b2_71jAaQs_UgyDrtDbtwBZRgFz4Jd4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# D-le Președinte,dacă nu aveți curajul,onoarea,puterea de a lupta cu mafia securisto-comunisto-rusofilă psdnl,dacă vă lăsați dominat de mafia securisto-rusofilă trădătoare din serviciile secrete trădătoare,aveți măcar bunul simț și plecați acasă.România nu mai poate gira incă un președinte slab,fricos,politruc,servil cu mafia securisto-rusofilă, care distruge viitorul țarii.Reacționați sau plecați!
# ================================================================================
# ID: yt_M37Lar0c11g_UgzqcSjMn379kcSJAZl4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Da-ți programul vizitei lui Cerşinski în România, sā-l întâmpinām cum se cuvine!
# ================================================================================
# ID: yt_bnbjgKIS5Dw_UgzlWxIqTksTiU4WQ2d4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# SI INCA CEVA ,APROPO DE ,,POLITICA POPILOR: IN ,,CAMPANIA ELECTORALA,,DOMUL" LEGIONARUL PRO-RUS DE GEORGESCU A FOST PRIMIT DE PARINTELE CALISTRAT LA VLADICENI-IASI ,CA SI POPA CALISTRAT ESTE LEGIONAR, IN BISERICA DE A DAT INTERVIU !!!!! DAR TOT LA VLADICENI-IASI,SE SPALA LA GREU BANI PRIN BISERICA, A FOST ,,INZESTRATA " MANASTIREA CU SUTE,SAU POATE MII DE HECTARE ...SA VENITI SA VEDETI..CE GARD MONUMENTAL A TRANTIT IN JURUL BISERICII !!!! DOAMNE IARTĂ-MĂ CA FAC PACATE CU EI IN ASA ZI SFANTA A SFANTULUI MINA!!!!!CU DEOSEBITA STIMA MARCELA LUPU DIN IAȘI/ROMÂNIA!!!!!🎉😊❤🎉😊❤
# ================================================================================
# ID: yt_yEuctxNb4O0_UgxNv47481MET5yGVVh4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Domnule Președinte luați atitudine , cine știe dacă nu pentru vremuri ca acestea Dumnezeu v a înălțat în cea mai înaltă dregătorie a statului .Sistemul de justiție al unei țări este important pentru Dumnezeu și pentru oameni .Justiția trebuie sa fie reflecția dreptății Lui . Legile pământești sunt reflecția legilor lui Dumnezeu ! O Românie onesta , incepe cu o justiție onesta , domnule Președinte! 🙏🤍
# ================================================================================
# ID: yt__KWvjqg67Fk_UgyF9mL_aCm1CFrIlb94AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# Am impresia că Digi sunt mâhniți că regimul terorist din Iran este distrus...Se vede o stare de nemulțumire că și noi contribuim la nimicirea teroriștilor și a sponsorilor lor. Când ”Gărzile revoluționare” ucideau în masă propria populație, zeci de mii de oameni, Digi nu se scandaliza în halul ăsta, dar acum, acum e prăpădul lumii că se stinge un regim criminal. Ipocriți și influențați demonic...
# ================================================================================
# ID: yt_Or2KQOKFZOw_UgwTlTWQbgMbG9gB6UB4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media_conspiratorial
# Un ordinar precum Grindeanu, nu are ce sa caute la guvernare. Locul lui e dupa gratii, dar pare ca nu se prea vrea 😠
# ================================================================================
# ID: yt_Or2KQOKFZOw_UgypoUiPXXOR5I44-KR4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Franța, alături de alte țări europene precum Grecia și Polonia, a plafonat prețul combustibililor şi a impus restricții asupra marjelor de profit pentru a combate impactul scumpirilor. DOAR IN ROMANIA E HOTIEEE. PLAFONATI ODATA LA 8 LEI CA SE MOARE DE FOAME , SE INCHID FIRME, AJUNGEM LA CARUTE. HOTI HOTI HOTI!
# ================================================================================
# ID: yt_OP3PA47JM_M_UgynbmYRghdhbUkdAwN4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Romania este falimentara . Nimeni nu o mai imprumuta . A fost refuzata. Băsescu dă verdictul care sperie România: 'Nu avem bani! Nu există marjă pentru ieftinirea carburanților ... România intră într-o zonă periculoasă din punct de vedere economic, avertizează fostul președinte Traian Băsescu, care susține că statul nu mai are nicio marjă reală de intervenție pentru a tempera explozia prețurilor la carburanți. Pregatiti-va de dezastru si nu mai cereti bani ..
# ================================================================================
# ID: yt_stxoPQZOAMU_UgzfOuVzOzHhgnM3brB4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media_conspiratorial
# Doamne ajuta. . Cu cit vrea sa va distrugă minciunile la România TV plus Becali a înnebunit in post Cu atât lumea va iubește .
# ================================================================================
# ID: yt_E5Rmj4r-bdw_UgwdutukA2M4npPR_lp4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Pesede trebuie să dispară. Un nou și serios partid social democrat trebuie să apară.
# ================================================================================
# ID: yt_bnbjgKIS5Dw_UgyaR47s4xHurcUk93N4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Dragă,doar pentru păcatele noastre este țara in halul in care este acum ! Tu de ce crezi ca meriți salariul de aprox.20.000 euro ca parlamentar? Lasă tu in pace Biserica !
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgwGdB2FSGz2S5KRmIB4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Florin Gheorghe Cârciu “sprijinește” 11:04 In prezent europarlamentar!
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgzoRJu2aWr817K8cU54AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# Pastele si grijania mamii lor (spus in stilul marelui Gh Dinica)!
# ================================================================================
# ID: yt_YFbJhBc_9jo_UgwexLND_5rYFgAziZt4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# se poate sustine si dela0 cu formularul 230? sau îți fură clienții? 😂 întreb pentru un prieten 🤣
# ================================================================================
# ID: yt_YFbJhBc_9jo_Ugwc9lOEzX2-a-4O31R4AaABAg
# Confidence: medium
# Subtype: grievance_epistemic_verificational
# Totusi, avem nevoie de biserici,mai ales când nu suntem acasă. Daca 20 de români intră in sărbători, duminici, in biserică ,înmulțiți cu 1300, înseamna că sunt români care au nevoie ; și ei sunt diaspora. Cred că aveți dreptate doar in parte. Investigați luxul unor slujitori ai bisericii,nu biserica in sine.
# ================================================================================
# ID: yt_YFbJhBc_9jo_Ugxu5hn3sXkR1kFV3Qt4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media_conspiratorial
# vocea asta e perfectă pentru telefon. nu e genul de voce la care ai închide. "sunt jurnalist la recorder" sună deja a jignire. Sigur au băgat AI să recunoască fraza să închidă automat 🤣🤣
# ================================================================================
# ID: yt_SGIT4lju_5s_UgzZxqHyujgHsIlOvzB4AaABAg
# Confidence: medium
# Subtype: grievance_mobilizator
# Am de 1000 de ori mai mare incredere cu viata mea la un dr. tanar decat la toate fosilele alea corupte si imbuibate! Asta v o zic din experienta proprie cu doctorii din Romania! Feriti va de toti asa zisii “profesori doctori” ca va omoara familiile dupa ce v au stors de spagi!
# ================================================================================
# ID: yt_dESUmtdVSzo_UgwsxLiHHNXnDrgwH5x4AaABAg
# Confidence: medium
# Subtype: grievance_anti_suveranist
# DE LA GEORGESCU PUTETI AȘTEPTA MULT SI BINE.... ȘI DE LA ORICARE ALT PERSONAJ AL IMEDIATULUI POLITIC?????.... ÎNCĂ NU ATI PATRUNS PREZENTUL - NU AȚI PUTUT VEDEA K ABSURDUL NU ARE SFÂRȘIT .....NICI NU SE VREA..... NOAPTE BUNA EUGEN IONESCO.....
# ================================================================================
# ID: yt_KETrGGaXRpk_UgzBNINvfTr3GJJkBeJ4AaABAg
# Confidence: medium
# Subtype: grievance_anti_media
# nu stiu de ce ne mai miram, comentam si asa mai departe… cat timp stam pasivi, cat timp acceptam si nu facem nimic, totul e doar o satira ca sa mai treaca timpul. Respect Robert, dar asta este realitatea.

# %%
# elimin textele slabe și păstrez 50

REMOVE_IDS = [
    # pune aici ID-urile textelor slabe
]

clean_df = (
    my_df[~my_df["id"].isin(REMOVE_IDS)]
    .head(50)
    .copy()
)

clean_df["agent"] = MY_AGENT
clean_df["slug"] = meta["slug"]
clean_df["personality"] = meta["personality"]
clean_df["speaks"] = meta["speaks"]
clean_df["definition"] = meta["definition"]

print("Texte finale:", len(clean_df))
clean_df[["id", "agent", "text"]].head()
# Out:
# Texte finale: 50
#                                               id        agent  \
# 15394  yt_joXkZDqGZQU_Ugyqb1XZ7P8GTnJS_4p4AaABAg  Anti-sistem
# 11534  yt_pO0JOPX1I7Q_UgyExKkzQjU2eOVTG7J4AaABAg  Anti-sistem
# 15409  yt_6_Hc2S02Duw_Ugz2UatUIFNpL1SP7u54AaABAg  Anti-sistem
# 7956   yt_YFbJhBc_9jo_Ugx9GFXKkTHUqa4NYcZ4AaABAg  Anti-sistem
# 7954   yt_YFbJhBc_9jo_UgzrK_gcZVEbQXhfL614AaABAg  Anti-sistem
#
#                                                     text
# 15394  Semneaza Bo$$ ca la urmatoarele alegerii nu ma...
# 11534  ESTE NEVOIE DE O FESTAÑIE LA TOATE NIVELURILE ...
# 15409  Orcii fac ore suplimentare!! Bravo! Daca ati m...
# 7956   Câtă nesimțire!!! Câtă hoție pe fațaă!!! Ce ră...
# 7954   Biserica, aceasta sinecura de sifonat bani, es...

# %% [markdown]
# ### Descrierea agentului tău
# Înainte să exporți bula curată, descrie în 5–7 rânduri ce fel de voce discursivă are agentul ales.
# Nu descrie o persoană reală. Descrie un tip de discurs observat în corpus.
# Răspunde la aceste întrebări:
# - Cum vede acest agent instituțiile, politica sau actorii publici?
# - Ce ton folosește cel mai des?
# - Ce tip de argumente sau acuzații apar frecvent?
# - Ce îl diferențiază de celelalte bule?
# - Ce ar trebui să păstreze un viitor agent AI ca să sune coerent cu această bulă?

# %% [markdown]
# descriere:
# -
# -
# -

# %%
# export bula curată pentru etapa următoare

OUT_DIR = Path("data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

out_path = OUT_DIR / f"{meta['slug']}.jsonl"

clean_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

print("Salvat:", out_path)
# Out:
# Salvat: data\bubbles\anti_sistem.jsonl
